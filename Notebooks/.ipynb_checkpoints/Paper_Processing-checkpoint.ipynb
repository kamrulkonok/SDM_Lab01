# %%
import pandas as pd
import numpy as np
import random

# %%
# Get data

df_papers = pd.read_csv('../konok_data/papers_data.csv')
df_papers.loc[df_papers['field_query'] == ' Big Data', 'field_query'] = 'Big Data' # Fixed Big Data spacing issue
df_papers.head()
# Out:
#   field_query                                   paperId  \
# 0         NLP  29ddc1f43f28af7c846515e32cc167bc66886d0c
# 1         NLP  58ed1fbaabe027345f7bb3a6312d41c5aac63e22
# 2         NLP  d6a083dad7114f3a39adc65c09bfbb6cf3fee9ea
# 3         NLP  06d7cb8c8816360feb33c3367073e0ef66d7d0b0
# 4         NLP  5471114e37448bea2457b74894b1ecb92bbcfdf6
#
#                                                title  \
# 0      Parameter-Efficient Transfer Learning for NLP
# 1  Retrieval-Augmented Generation for Knowledge-I...
# 2  Energy and Policy Considerations for Deep Lear...
# 3  Super-NaturalInstructions: Generalization via ...
# 4  From Pretraining Data to Language Models to Do...
#
#                                                  url  \
# 0  https://www.semanticscholar.org/paper/29ddc1f4...
# 1  https://www.semanticscholar.org/paper/58ed1fba...
# 2  https://www.semanticscholar.org/paper/d6a083da...
# 3  https://www.semanticscholar.org/paper/06d7cb8c...
# 4  https://www.semanticscholar.org/paper/5471114e...
#
#                                                venue  \
# 0       International Conference on Machine Learning
# 1              Neural Information Processing Systems
# 2  Annual Meeting of the Association for Computat...
# 3  Conference on Empirical Methods in Natural Lan...
# 4  Annual Meeting of the Association for Computat...
#
#                    publicationTypes  \
# 0  ['JournalArticle', 'Conference']
# 1                ['JournalArticle']
# 2  ['JournalArticle', 'Conference']
# 3  ['JournalArticle', 'Conference']
# 4  ['JournalArticle', 'Conference']
#
#                                             abstract  year  citationCount  \
# 0  Fine-tuning large pre-trained models is an eff...  2019           2453
# 1  Large pre-trained language models have been sh...  2020           1686
# 2  Recent progress in hardware and methodology fo...  2019           2113
# 3  How well can NLP models generalize to a variet...  2022            432
# 4  Language models (LMs) are pretrained on divers...  2023             72
#
#   journal_name  journal_volume journal_pages
# 0        ArXiv  abs/1902.00751           NaN
# 1        ArXiv  abs/2005.11401           NaN
# 2        ArXiv  abs/1906.02243           NaN
# 3          NaN             NaN     5085-5109
# 4        ArXiv  abs/2305.08283           NaN

# %%
df_papers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   field_query       1200 non-null   object
#  1   paperId           1200 non-null   object
#  2   title             1200 non-null   object
#  3   url               1200 non-null   object
#  4   venue             1122 non-null   object
#  5   publicationTypes  1034 non-null   object
#  6   abstract          892 non-null    object
#  7   year              1200 non-null   int64
#  8   citationCount     1200 non-null   int64
#  9   journal_name      1038 non-null   object
#  10  journal_volume    776 non-null    object
#  11  journal_pages     645 non-null    object
# dtypes: int64(2), object(10)
# memory usage: 112.6+ KB

# %%
df_papers['field_query'].value_counts()
# Out:
# NLP                  100
# Machine Learning     100
# LLM                  100
# Deep Learning        100
# Quantum Computing    100
# Graph Database       100
# Data Management      100
# Data Modeling        100
# Big Data             100
# Data Processing      100
# Data Storage         100
# Data Querying        100
# Name: field_query, dtype: int64

# %% [markdown]
# # Cleanup Data
#
# Check if the venue is missing and if it can be used

# %%
df_papers.query('venue != venue')
# Out:
#            field_query                                   paperId  \
# 45                 NLP  8bb9db78b4413b92cdeeae9e24e955aab9c87ae1
# 75                 NLP  db528269ef800727245c0fcb35b692d29c1ccdc9
# 112   Machine Learning  5c39e37022661f81f79e481240ed9b175dec6513
# 119   Machine Learning  2936cbd6a90d7153a9fa34e8e4fd947907fe7f6c
# 120   Machine Learning  eb9e0da8b7170e3ca4364f2f9010599c2d2556f1
# ...                ...                                       ...
# 1064      Data Storage  156d8e2aa90b5ccc9be10477ca70deaad0151387
# 1071      Data Storage  6c34842a92ce4da9aab586490afdbd8779af4eab
# 1090      Data Storage  ba687027ed6012f613e1f9a9cefe7683bb192934
# 1133     Data Querying  32a849fe3020144e5ba82ba0442ac571f554ca31
# 1150     Data Querying  590b617c08d34bc6caed7e4490c0b22a9c516e86
#
#                                                   title  \
# 45    A Survey of Adversarial Defences and Robustnes...
# 75    Natural language processing (NLP) in managemen...
# 112   Towards A Rigorous Science of Interpretable Ma...
# 119   Hands-On Machine Learning with Scikit-Learn an...
# 120                        Machine Learning With Python
# ...                                                 ...
# 1064  MongoDB - The Definitive Guide: Powerful and S...
# 1071  Blockchain Based Data Storage Mechanism in Cyb...
# 1090  Optical Data Storage and Multicolor Emission R...
# 1133  Analyzing Data for Decision Making: Integratin...
# 1150  Querying linked building data using SPARQL wit...
#
#                                                     url venue  \
# 45    https://www.semanticscholar.org/paper/8bb9db78...   NaN
# 75    https://www.semanticscholar.org/paper/db528269...   NaN
# 112   https://www.semanticscholar.org/paper/5c39e370...   NaN
# 119   https://www.semanticscholar.org/paper/2936cbd6...   NaN
# 120   https://www.semanticscholar.org/paper/eb9e0da8...   NaN
# ...                                                 ...   ...
# 1064  https://www.semanticscholar.org/paper/156d8e2a...   NaN
# 1071  https://www.semanticscholar.org/paper/6c34842a...   NaN
# 1090  https://www.semanticscholar.org/paper/ba687027...   NaN
# 1133  https://www.semanticscholar.org/paper/32a849fe...   NaN
# 1150  https://www.semanticscholar.org/paper/590b617c...   NaN
#
#      publicationTypes                                           abstract  \
# 45         ['Review']  In the past few years, it has become increasin...
# 75         ['Review']  Natural language processing (NLP) is gaining m...
# 112               NaN  As machine learning systems become ubiquitous,...
# 119               NaN  Through a series of recent breakthroughs, deep...
# 120               NaN                                                NaN
# ...               ...                                                ...
# 1064              NaN                                                NaN
# 1071              NaN  As cyber-physical systems (CPS) flourish, the ...
# 1090              NaN  The fast‐growing amount of data that is produc...
# 1133              NaN  ABSTRACT: Although students begin with a sprea...
# 1150              NaN  In this paper, we propose to extend SPARQL fun...
#
#       year  citationCount                    journal_name journal_volume  \
# 45    2022             23                             NaN            NaN
# 75    2020            174                             NaN              7
# 112   2017           2936         arXiv: Machine Learning            NaN
# 119   2017           2519                             NaN            NaN
# 120   2019           2079                             NaN            NaN
# ...    ...            ...                             ...            ...
# 1064  2019            256                             NaN            NaN
# 1071  2020             25  Journal of Internet Technology             21
# 1090  2018            226   Advanced Functional Materials             28
# 1133  2017             16  Issues in Accounting Education             32
# 1150  2016             16                             NaN            NaN
#
#       journal_pages
# 45              NaN
# 75          139-172
# 112             NaN
# 119             NaN
# 120             NaN
# ...             ...
# 1064  I-XVII, 1-193
# 1071      1681-1689
# 1090            NaN
# 1133          59-66
# 1150            NaN
#
# [78 rows x 12 columns]

# %% [markdown]
# Based on this, venue seems useless. Therefore, I will remove these datapoints.Similarily remove other stuff as well. Keep only useful and complete stuff for now.

# %%
df_papers = df_papers.dropna(subset=['venue'])
df_papers = df_papers.dropna(subset=['publicationTypes'])
df_papers = df_papers.dropna(subset=['abstract'])
df_papers = df_papers.drop(columns=['journal_pages']) # its not needed

df_papers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 771 entries, 0 to 1199
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   field_query       771 non-null    object
#  1   paperId           771 non-null    object
#  2   title             771 non-null    object
#  3   url               771 non-null    object
#  4   venue             771 non-null    object
#  5   publicationTypes  771 non-null    object
#  6   abstract          771 non-null    object
#  7   year              771 non-null    int64
#  8   citationCount     771 non-null    int64
#  9   journal_name      686 non-null    object
#  10  journal_volume    515 non-null    object
# dtypes: int64(2), object(9)
# memory usage: 72.3+ KB

# %%
# Filter rows where 'venue' contains 'Workshop' after filling NaN values
workshop_rows = df_papers[df_papers['venue'].fillna('').str.contains('Workshop')]

# Change the value of 'publicationTypes' to 'Workshop' for the filtered rows
df_papers.loc[workshop_rows.index, 'publicationTypes'] = "['Workshop']"

# %%
# Filter rows where 'publicationTypes' contains 'Conference' after filling NaN values
conference_rows = df_papers[df_papers['publicationTypes'].fillna('').str.contains('Conference')]

# Change the value of 'publicationTypes' to 'Conference' for the filtered rows
df_papers.loc[conference_rows.index, 'publicationTypes'] = "['Conference']"

# %%
df_papers['publicationTypes'].value_counts()
# Out:
# ['JournalArticle']                      371
# ['Conference']                          185
# ['JournalArticle', 'Review']            123
# ['Review']                               38
# ['Review', 'JournalArticle']             24
# ['Workshop']                             11
# ['JournalArticle', 'Book']               10
# ['Book', 'JournalArticle']                4
# ['Book', 'JournalArticle', 'Review']      1
# ['Book']                                  1
# ['Study', 'JournalArticle']               1
# ['JournalArticle', 'Study']               1
# ['CaseReport', 'Review']                  1
# Name: publicationTypes, dtype: int64

# %%
# Only Keep the three for now

allowed_values = ["['JournalArticle']", "['Conference']", "['Workshop']"]
df_papers = df_papers[df_papers['publicationTypes'].isin(allowed_values)]

df_papers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 567 entries, 0 to 1198
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   field_query       567 non-null    object
#  1   paperId           567 non-null    object
#  2   title             567 non-null    object
#  3   url               567 non-null    object
#  4   venue             567 non-null    object
#  5   publicationTypes  567 non-null    object
#  6   abstract          567 non-null    object
#  7   year              567 non-null    int64
#  8   citationCount     567 non-null    int64
#  9   journal_name      484 non-null    object
#  10  journal_volume    366 non-null    object
# dtypes: int64(2), object(9)
# memory usage: 53.2+ KB

# %%
df_papers['publicationTypes'] = df_papers['publicationTypes'].str[2:-2]
df_papers.head()
# Out:
#   field_query                                   paperId  \
# 0         NLP  29ddc1f43f28af7c846515e32cc167bc66886d0c
# 1         NLP  58ed1fbaabe027345f7bb3a6312d41c5aac63e22
# 2         NLP  d6a083dad7114f3a39adc65c09bfbb6cf3fee9ea
# 3         NLP  06d7cb8c8816360feb33c3367073e0ef66d7d0b0
# 4         NLP  5471114e37448bea2457b74894b1ecb92bbcfdf6
#
#                                                title  \
# 0      Parameter-Efficient Transfer Learning for NLP
# 1  Retrieval-Augmented Generation for Knowledge-I...
# 2  Energy and Policy Considerations for Deep Lear...
# 3  Super-NaturalInstructions: Generalization via ...
# 4  From Pretraining Data to Language Models to Do...
#
#                                                  url  \
# 0  https://www.semanticscholar.org/paper/29ddc1f4...
# 1  https://www.semanticscholar.org/paper/58ed1fba...
# 2  https://www.semanticscholar.org/paper/d6a083da...
# 3  https://www.semanticscholar.org/paper/06d7cb8c...
# 4  https://www.semanticscholar.org/paper/5471114e...
#
#                                                venue publicationTypes  \
# 0       International Conference on Machine Learning       Conference
# 1              Neural Information Processing Systems   JournalArticle
# 2  Annual Meeting of the Association for Computat...       Conference
# 3  Conference on Empirical Methods in Natural Lan...       Conference
# 4  Annual Meeting of the Association for Computat...       Conference
#
#                                             abstract  year  citationCount  \
# 0  Fine-tuning large pre-trained models is an eff...  2019           2453
# 1  Large pre-trained language models have been sh...  2020           1686
# 2  Recent progress in hardware and methodology fo...  2019           2113
# 3  How well can NLP models generalize to a variet...  2022            432
# 4  Language models (LMs) are pretrained on divers...  2023             72
#
#   journal_name  journal_volume
# 0        ArXiv  abs/1902.00751
# 1        ArXiv  abs/2005.11401
# 2        ArXiv  abs/1906.02243
# 3          NaN             NaN
# 4        ArXiv  abs/2305.08283

# %%
df_papers['publicationTypes'].value_counts()
# Out:
# JournalArticle    371
# Conference        185
# Workshop           11
# Name: publicationTypes, dtype: int64

# %%
df_papers['journal_name']
# Out:
# 0                                                   ArXiv
# 1                                                   ArXiv
# 2                                                   ArXiv
# 3                                                     NaN
# 4                                                   ArXiv
#                               ...
# 1191    Proceedings of the 2016 International Conferen...
# 1194    Proceedings of the 2017 ACM International Conf...
# 1195                               Nucleic Acids Research
# 1197                                                  NaN
# 1198    2017 IEEE 33rd International Conference on Dat...
# Name: journal_name, Length: 567, dtype: object

# %%
# Working on journal_volume

# Identify rows where 'publicationTypes' is either 'Workshop' or 'Conference'
mask = df_papers['publicationTypes'].isin(['Workshop', 'Conference'])

# Set corresponding values in 'journal_volume' to an empty string
df_papers.loc[mask, 'journal_volume'] = ""
# Out:
# 7                 18
# 9                 17
# 8                 13
# 6                  8
# 16                 8
#                   ..
# abs/2308.08241     1
# abs/2309.13788     1
# abs/2306.13304     1
# abs/2305.13711     1
# 38                 1
# Name: journal_volume, Length: 186, dtype: int64

# %%
df_papers['journal_volume'].isna().sum()
# Out:
# 43

# %%
# implies there are NaN values for Journals too. So, we need to remove them.
df_papers = df_papers.dropna(subset=['journal_volume'])
df_papers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 524 entries, 0 to 1198
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   field_query       524 non-null    object
#  1   paperId           524 non-null    object
#  2   title             524 non-null    object
#  3   url               524 non-null    object
#  4   venue             524 non-null    object
#  5   publicationTypes  524 non-null    object
#  6   abstract          524 non-null    object
#  7   year              524 non-null    int64
#  8   citationCount     524 non-null    int64
#  9   journal_name      457 non-null    object
#  10  journal_volume    524 non-null    object
# dtypes: int64(2), object(9)
# memory usage: 49.1+ KB

# %%
# check if all journals have journal names or not
df_papers.query('publicationTypes == "JournalArticle"')['journal_volume'].isna().sum()
# Out:
# 0

# %% [markdown]
# Note : Currently the following information is missing
#
# - Edition (19th etc)
# - Venue should be the location
# - Journal name would be changed to publication type name (basically the stuff inside venue)
# - Add the AuthorIds of the papers in this dataset
#
# For Evolution part, I have to add the following :
# - Reviewer
# - Comments
# - Approved or Not

# %%
df_papers.to_csv('../aryan_data/papers_info.csv', index=False)
